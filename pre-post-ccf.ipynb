# %% [markdown]
# # Compile pre- and post-ICB CCFs for mutations
#
# TODO: Need to get OncoKB and CADD annotations for these mutations

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load data

# %%
# Mutation data
mut_ccf_df = pd.read_pickle("data/icb_wes_mut_ccfs_maf.pickle")

# Participant metadata
pt_df = pd.read_csv("data/participant_cohort_sheet.tsv", sep="\t")
sample_df = pd.read_csv("data/sample_cohort_sheet.tsv", sep="\t")

# Deleteriousness annotations
del_df = pd.read_csv("data/annotated_nf1_mut_ccfs.tsv", sep="\t")

# %% [markdown]
# # Clean data

# %%
def clean_sample_id(sid):
    if sid.endswith("_pair"):
        return sid[:-5]
    else:
        return sid

complements = {"G": "C",
               "C": "G",
               "A": "T",
               "T": "A"
              }

def clean_ref_alt(ref, alt):
    if ref in ("G", "A"):
        if alt != "-":
            ref = complements[ref]
            alt = complements[alt]
    return ref, alt

# %%
mut_ccf_df["Sample_ID"] = mut_ccf_df["Sample_ID"].map(clean_sample_id)

mut_ccf_df["sbs"] = mut_ccf_df[["Reference_Allele", "Tumor_Seq_Allele"]].apply(lambda r: clean_ref_alt(r["Reference_Allele"], 
                                                                                                       r["Tumor_Seq_Allele"]
                                                                                                      ),
                                                                               axis=1
                                                                              )
mut_ccf_df["Reference_Allele"] = mut_ccf_df["sbs"].map(lambda x: x[0])
mut_ccf_df["Tumor_Seq_Allele"] = mut_ccf_df["sbs"].map(lambda x: x[1])

mut_ccf_df = mut_ccf_df.rename(columns={"Start_position": "Start_Position",
                                        "Tumor_Seq_Allele": "Tumor_Seq_Allele2"
                                        }
                                )

# %% [markdown]
# # Obtain latest pre- and earliest post-ICB WES samples for each participant

# %%
sample_df = sample_df[sample_df["usable_wes"] & (sample_df["tumor_normal"] == "tumor")]

# %%
sample_df = sample_df.merge(pt_df[["participant_id_legacy", "DaysDxtoICB"]], left_on="participant_id_legacy", right_on="participant_id_legacy", how="left")

# %%
sample_df["collection_days_from_icb"] = sample_df["collection_date_dfd"] - sample_df["DaysDxtoICB"]

# %%
pre_sample_df = sample_df[sample_df["collection_days_from_icb"] <= 0]
post_sample_df = sample_df[sample_df["collection_days_from_icb"] > 0]

# %%
latest_pre_dates = pre_sample_df[["participant_id_legacy", "collection_days_from_icb"]].groupby("participant_id_legacy").max().rename(columns={"collection_days_from_icb": "latest_pre_date"})
earliest_post_dates = post_sample_df[["participant_id_legacy", "collection_days_from_icb"]].groupby("participant_id_legacy").min().rename(columns={"collection_days_from_icb": "earliest_post_date"})

# %%
pre_sample_df = pre_sample_df.merge(latest_pre_dates, left_on="participant_id_legacy", right_index=True)
post_sample_df = post_sample_df.merge(earliest_post_dates, left_on="participant_id_legacy", right_index=True)

# %%
pre_sample_df = pre_sample_df[pre_sample_df["collection_days_from_icb"] == pre_sample_df["latest_pre_date"]]
post_sample_df = post_sample_df[post_sample_df["collection_days_from_icb"] == post_sample_df["earliest_post_date"]]

# %%
latest_pre_samples = set(pre_sample_df["sample_id_legacy"]) | set(pre_sample_df["aliases"].dropna())
earliest_post_samples = set(post_sample_df["sample_id_legacy"]) | set(post_sample_df["aliases"].dropna())

relevant_samples = set(latest_pre_samples) | set(earliest_post_samples)

# %%
latest_pre_sample_df = (pre_sample_df[pre_sample_df['sample_id_legacy'].isin(latest_pre_samples)]
                        #.rename(columns={"collection_days_from_icb": "pre_collection_days_from_icb"})
                       )
earliest_post_sample_df = (post_sample_df[post_sample_df['sample_id_legacy'].isin(earliest_post_samples)]
                           #.rename(columns={"collection_days_from_icb": "post_collection_days_from_icb"})
                          )

# %% [markdown]
# # Get pre- and post-ICB mean CCFs for these mutations

# %%
pre_muts = mut_ccf_df[mut_ccf_df["Sample_ID"].isin(latest_pre_samples)]
post_muts = mut_ccf_df[mut_ccf_df["Sample_ID"].isin(earliest_post_samples)]

# %%
pre_mut_ccfs = (pre_muts.groupby(["Patient_ID", "unique_mut_id"])["clust_ccf_mean"]
                .mean()
                .reset_index()
                .rename(columns={"clust_ccf_mean": "pre_ccf_mean",
                                }
                ))
post_mut_ccfs = (post_muts.groupby(["Patient_ID", "unique_mut_id"])["clust_ccf_mean"]
                 .mean()
                 .reset_index()
                 .rename(columns={"clust_ccf_mean":"post_ccf_mean",
                                 }
                ))

# %%
kept_cols = ["Patient_ID", "Sample_ID", "Hugo_Symbol", "Chromosome", "Start_Position", 
             "Reference_Allele", "Tumor_Seq_Allele2", "unique_mut_id", "Cluster_Assignment", "clonal_status"]
mut_df = mut_ccf_df[kept_cols].drop_duplicates()

# %%
mut_df = (mut_df.merge(pre_mut_ccfs, left_on=["Patient_ID", "unique_mut_id"], right_on=["Patient_ID", "unique_mut_id"], how="left")
                .merge(post_mut_ccfs, left_on=["Patient_ID", "unique_mut_id"], right_on=["Patient_ID", "unique_mut_id"], how="left")
                .merge(latest_pre_sample_df[["participant_id_legacy", "latest_pre_date"]], left_on="Patient_ID", right_on="participant_id_legacy", how="left")
                .drop(columns=["participant_id_legacy"])
                .merge(earliest_post_sample_df[["participant_id_legacy", "earliest_post_date"]], left_on="Patient_ID", right_on="participant_id_legacy", how="left")
                .drop(columns=["participant_id_legacy"])
                .sort_values(["Patient_ID", "Chromosome", "Start_Position"])
                .reset_index(drop=True)
                .drop_duplicates(["Patient_ID", "unique_mut_id"])
         )

# %%
mut_df[mut_df["Hugo_Symbol"] == "NF1"].shape#.to_csv("mutations_w_prepost_ccfs_nf1.tsv", sep="\t", index=None)
# Out:
# (54, 14)

# %% [markdown]
# # Join deleteriousness annotations

# %%
del_df["sbs"] = del_df[["Reference_Allele", "Tumor_Seq_Allele"]].apply(lambda r: clean_ref_alt(r["Reference_Allele"], 
                                                                                               r["Tumor_Seq_Allele"]
                                                                                              ),
                                                                       axis=1
                                                                              )
del_df["Reference_Allele"] = del_df["sbs"].map(lambda x: x[0])
del_df["Tumor_Seq_Allele"] = del_df["sbs"].map(lambda x: x[1])
del_df["Chromosome"] = del_df["Chromosome"].astype(str)

# %%
del_df = del_df.rename(columns={"Start_position": "Start_Position",
                                "Tumor_Seq_Allele": "Tumor_Seq_Allele2"
                               }
                      )

# %%
join_cols = ["Chromosome", "Start_Position", "Reference_Allele", "Tumor_Seq_Allele2"]

del_df[join_cols] = del_df[join_cols].astype(str)
del_df = del_df[join_cols + ["CADD_PHRED", "ONCOKB_MUTATION_EFFECT", "cadd_oncokb_deleterious"]].drop_duplicates()

mut_df[join_cols] = mut_df[join_cols].astype(str)
mut_df = mut_df.merge(del_df, left_on=join_cols, right_on=join_cols, how="left")

# %%
nf1_paired_mut_df = mut_df[(mut_df["Hugo_Symbol"] == "NF1") &\
                           (mut_df["pre_ccf_mean"].notnull()) &\
                           (mut_df["post_ccf_mean"].notnull())]

# %%
nf1_paired_mut_df.to_csv("mutations_w_prepost_ccfs_nf1.tsv", sep="\t", index=None)

# %%
nf1_paired_mut_df
# Out:
#          Patient_ID                        Sample_ID Hugo_Symbol Chromosome  \
# 8583      GBM.ICB-1          GBM.ICB-1-10.533.B1.Pre         NF1         17
# 8584      GBM.ICB-1          GBM.ICB-1-10.533.B1.Pre         NF1         17
# 8585      GBM.ICB-1          GBM.ICB-1-10.533.B1.Pre         NF1         17
# 8587      GBM.ICB-1          GBM.ICB-1-10.533.B1.Pre         NF1         17
# 8588      GBM.ICB-1          GBM.ICB-1-10.533.B1.Pre         NF1         17
# 26769    GBM.ICB-10     GBM.ICB-10-14.178.B.Pre2.FFc         NF1         17
# 26770    GBM.ICB-10     GBM.ICB-10-14.178.B.Pre2.FFc         NF1         17
# 43600   GBM.ICB-131     GBM.ICB-131-16.577.2-1.u.Pre         NF1         17
# 43601   GBM.ICB-131     GBM.ICB-131-16.577.2-1.u.Pre         NF1         17
# 43602   GBM.ICB-131     GBM.ICB-131-16.577.2-1.u.Pre         NF1         17
# 43603   GBM.ICB-131     GBM.ICB-131-16.577.2-1.u.Pre         NF1         17
# 43604   GBM.ICB-131     GBM.ICB-131-16.577.2-1.u.Pre         NF1         17
# 43605   GBM.ICB-131     GBM.ICB-131-16.577.2-1.u.Pre         NF1         17
# 43606   GBM.ICB-131     GBM.ICB-131-16.577.2-1.u.Pre         NF1         17
# 43611   GBM.ICB-131     GBM.ICB-131-16.577.2-1.u.Pre         NF1         17
# 43612   GBM.ICB-131     GBM.ICB-131-16.577.2-1.u.Pre         NF1         17
# 43613   GBM.ICB-131     GBM.ICB-131-16.577.2-1.u.Pre         NF1         17
# 43614   GBM.ICB-131     GBM.ICB-131-16.577.2-1.u.Pre         NF1         17
# 43615   GBM.ICB-131     GBM.ICB-131-16.577.2-1.u.Pre         NF1         17
# 43616   GBM.ICB-131     GBM.ICB-131-16.577.2-1.u.Pre         NF1         17
# 43617   GBM.ICB-131     GBM.ICB-131-16.577.2-1.u.Pre         NF1         17
# 68655    GBM.ICB-14         GBM.ICB-14-15.392.B1.Pre         NF1         17
# 81134     GBM.ICB-2          GBM.ICB-2-10.764-Pre.B2         NF1         17
# 82587    GBM.ICB-20       GBM.ICB-20-15.769.B1.u.Pre         NF1         17
# 90292    GBM.ICB-22       GBM.ICB-22-16.173.B1.u.Pre         NF1         17
# 90293    GBM.ICB-22       GBM.ICB-22-16.173.B1.u.Pre         NF1         17
# 90578    GBM.ICB-23     GBM.ICB-23-16.087-Pre.uss.B1         NF1         17
# 111488  GBM.ICB-243       GBM.ICB-243-17.963.FFc-Pre         NF1         17
# 126494  GBM.ICB-262      GBM.ICB-262-19.557-FFb-Pre2         NF1         17
# 134910   GBM.ICB-42  GBM.ICB-42-14.422.A1B1_C1.u.Pre         NF1         17
# 139748   GBM.ICB-75     GBM.ICB-75-15.111.Pre.FFbank         NF1         17
# 139749   GBM.ICB-75     GBM.ICB-75-15.111.Pre.FFbank         NF1         17
# 141725   GBM.ICB-84            GBM.ICB-84-16.832.Pre         NF1         17
#
#        Start_Position Reference_Allele Tumor_Seq_Allele2      unique_mut_id  \
# 8583         29550543                C                 T     17:29550543G>A
# 8584         29553685                C                 T     17:29553685G>A
# 8585         29556107                C                 T     17:29556107C>T
# 8587         29663438                C                 T     17:29663438G>A
# 8588         29664881                C                 T     17:29664881G>A
# 26769        29647432                C                 T     17:29647432C>T
# 26770        29665798                C                 T     17:29665798C>T
# 43600        29486094                C                 T     17:29486094G>A
# 43601        29527470                C                 T     17:29527470C>T
# 43602        29533315                C                 T     17:29533315C>T
# 43603        29554298                C                 T     17:29554298G>A
# 43604        29559818                C                 T     17:29559818G>A
# 43605        29587492                C                 T     17:29587492G>A
# 43606        29587502                C                 T     17:29587502G>A
# 43611        29653316             ACTA                 -  17:29653316ACTA>-
# 43612        29654547                C                 T     17:29654547G>A
# 43613        29654799                C                 T     17:29654799C>T
# 43614        29665815                C                 T     17:29665815C>T
# 43615        29679385                C                 T     17:29679385G>A
# 43616        29687631                C                 T     17:29687631C>T
# 43617        29701059                C                 T     17:29701059C>T
# 68655        29587502                C                 A     17:29587502G>T
# 81134        29562981                C                 T     17:29562981C>T
# 82587        29663915                C                 G     17:29663915C>G
# 90292        29664600                G                 -     17:29664600G>-
# 90293        29684085                C                 T     17:29684085C>T
# 90578        29553477                -                 C     17:29553477->C
# 111488       29653028                C                 T     17:29653028G>A
# 126494       29483141                T                 -     17:29483141T>-
# 134910       29483122                T                 -     17:29483122T>-
# 139748       29553477                -                 C     17:29553477->C
# 139749       29585518                T                 C     17:29585518A>G
# 141725       29562738               CT                 -    17:29562738CT>-
#
#         Cluster_Assignment clonal_status  pre_ccf_mean  post_ccf_mean  \
# 8583                     9     subclonal          0.01       0.280000
# 8584                     6     subclonal          0.01       0.900000
# 8585                     8     subclonal          0.01       0.010000
# 8587                     9     subclonal          0.01       0.280000
# 8588                     9     subclonal          0.01       0.280000
# 26769                   11     subclonal          0.01       0.010000
# 26770                   11     subclonal          0.01       0.010000
# 43600                    9     subclonal          0.01       0.010000
# 43601                   15     subclonal          0.01       0.010000
# 43602                   12     subclonal          0.64       0.010000
# 43603                   15     subclonal          0.01       0.010000
# 43604                   10     subclonal          0.01       0.940000
# 43605                   15     subclonal          0.01       0.010000
# 43606                   15     subclonal          0.01       0.010000
# 43611                    1        clonal          0.95       1.000000
# 43612                   10     subclonal          0.01       0.940000
# 43613                    9     subclonal          0.01       0.010000
# 43614                   15     subclonal          0.01       0.010000
# 43615                   15     subclonal          0.01       0.010000
# 43616                   15     subclonal          0.01       0.010000
# 43617                   15     subclonal          0.01       0.010000
# 68655                    7     subclonal          0.02       0.010000
# 81134                   15     subclonal          0.01       0.026000
# 82587                    1        clonal          0.97       0.900000
# 90292                    1        clonal          0.99       0.970000
# 90293                    1        clonal          0.99       0.970000
# 90578                    2     subclonal          0.36       0.080000
# 111488                   8     subclonal          0.01       0.016667
# 126494                   6     subclonal          0.79       0.035000
# 134910                   4     subclonal          0.01       1.000000
# 139748                   1        clonal          0.96       1.000000
# 139749                   1        clonal          0.96       1.000000
# 141725                   6     subclonal          0.01       0.010000
#
#         latest_pre_date  earliest_post_date  CADD_PHRED  \
# 8583            -1786.0                98.0       11.27
# 8584            -1786.0                98.0       29.30
# 8585            -1786.0                98.0       24.80
# 8587            -1786.0                98.0       28.00
# 8588            -1786.0                98.0       42.00
# 26769            -807.0                14.0       26.10
# 26770            -807.0                14.0       26.50
# 43600             -83.0               355.0       25.50
# 43601             -83.0               355.0       24.60
# 43602             -83.0               355.0       38.00
# 43603             -83.0               355.0       29.20
# 43604             -83.0               355.0       23.20
# 43605             -83.0               355.0       41.00
# 43606             -83.0               355.0       26.80
# 43611             -83.0               355.0         NaN
# 43612             -83.0               355.0       22.80
# 43613             -83.0               355.0       31.00
# 43614             -83.0               355.0       28.20
# 43615             -83.0               355.0       23.80
# 43616             -83.0               355.0       29.40
# 43617             -83.0               355.0        8.57
# 68655            -125.0                14.0       42.00
# 81134            -406.0               203.0       37.00
# 82587             -35.0               202.0       41.00
# 90292             -30.0               110.0         NaN
# 90293             -30.0               110.0       42.00
# 90578             -21.0               134.0         NaN
# 111488           -486.0               431.0       24.10
# 126494            -34.0               502.0         NaN
# 134910           -646.0               187.0         NaN
# 139748            -30.0              1148.0         NaN
# 139749            -30.0              1148.0       30.00
# 141725            -29.0                55.0         NaN
#
#        ONCOKB_MUTATION_EFFECT cadd_oncokb_deleterious
# 8583                  Unknown                   False
# 8584                  Unknown                    True
# 8585                  Unknown                    True
# 8587                  Unknown                    True
# 8588                  Unknown                    True
# 26769                 Unknown                    True
# 26770                 Unknown                    True
# 43600                 Unknown                    True
# 43601                 Unknown                    True
# 43602                 Unknown                    True
# 43603                 Unknown                    True
# 43604                 Unknown                    True
# 43605                 Unknown                    True
# 43606                 Unknown                    True
# 43611                 Unknown                   False
# 43612                 Unknown                    True
# 43613                 Unknown                    True
# 43614                 Unknown                    True
# 43615                 Unknown                    True
# 43616                 Unknown                    True
# 43617                 Unknown                   False
# 68655                 Unknown                    True
# 81134                 Unknown                    True
# 82587                 Unknown                    True
# 90292                 Unknown                   False
# 90293                 Unknown                    True
# 90578                 Unknown                   False
# 111488                Unknown                    True
# 126494                Unknown                   False
# 134910                Unknown                   False
# 139748                Unknown                   False
# 139749                Unknown                    True
# 141725                Unknown                   False

# %%
latest_pre_sample_df
# Out:
#         sample_id                    Broad_Name_add           Histology  \
# 0    GBM-001-T-1B                               NaN      Giant cell GBM
# 3     GBM-010-T-1                               NaN                 gbm
# 9     GBM-102-T-1                               NaN                 gbm
# 20    GBM-131-T-1                               NaN         gliosarcoma
# 23    GBM-136-T-1     GBM.ICB-136-16.350.A2.Pre.add                 NaN
# 26   GBM-139-T-1A                               NaN                 NaN
# 27   GBM-139-T-1B                               NaN                 NaN
# 28   GBM-139-T-1C                               NaN                 NaN
# 32    GBM-014-T-2                               NaN                 gbm
# 35    GBM-141-T-1     GBM.ICB-141-15.700.1B.Pre.add                 NaN
# 37    GBM-142-T-1                               NaN                 NaN
# 40    GBM-144-T-2                               NaN                 NaN
# 43    GBM-147-T-1                               NaN                 NaN
# 44    GBM-153-T-2                               NaN                 NaN
# 47    GBM-017-T-2                               NaN                 gbm
# 50    GBM-178-T-1                               NaN                 NaN
# 54    GBM-018-T-1                               NaN                 gbm
# 60    GBM-190-T-2                               NaN                 NaN
# 68    GBM-002-T-2                               NaN                 gbm
# 75    GBM-020-T-2                               NaN                 gbm
# 77   GBM-021-T-1A                               NaN                 gbm
# 78   GBM-021-T-1B                               NaN                 gbm
# 82    GBM-212-T-1                               NaN                 NaN
# 86    GBM-022-T-1                               NaN                 gbm
# 87   GBM-023-T-1A                               NaN                 gbm
# 88   GBM-023-T-1B                               NaN                 gbm
# 93    GBM-232-T-3                               NaN                 NaN
# 101   GBM-243-T-1                               NaN                 NaN
# 106   GBM-249-T-1                               NaN                 NaN
# 107   GBM-025-T-1                               NaN                 gbm
# 110   GBM-252-T-2                               NaN                 NaN
# 112   GBM-253-T-1                               NaN                 NaN
# 114   GBM-254-T-1                               NaN                 NaN
# 118   GBM-256-T-1                               NaN                 NaN
# 121   GBM-259-T-1                               NaN                 NaN
# 123   GBM-026-T-1                               NaN                 gbm
# 127   GBM-260-T-1                               NaN                 NaN
# 128   GBM-262-T-2                               NaN   gbm w/ giant cell
# 133   GBM-027-T-1                               NaN                 gbm
# 134   GBM-028-T-2                               NaN                 gbm
# 141   GBM-030-T-1                               NaN                 gbm
# 142   GBM-031-T-1                               NaN                 gbm
# 144  GBM-032-T-1A                               NaN                 NaN
# 145  GBM-032-T-1B                               NaN                 gbm
# 150   GBM-036-T-1                               NaN                 gbm
# 156   GBM-037-T-1                               NaN                 gbm
# 161   GBM-039-T-1                               NaN                   ?
# 165   GBM-004-T-1                               NaN                 gbm
# 168   GBM-042-T-1  GBM.ICB-42-14.422.A1B1.u.Pre.add                 NaN
# 170   GBM-043-T-1                               NaN                 NaN
# 172   GBM-006-T-1                               NaN      Giant cell GBM
# 174   GBM-069-T-2                               NaN                 gbm
# 179   GBM-007-T-3                               NaN  GBM w/ sarcomatoid
# 182   GBM-075-T-1                               NaN                 gbm
# 190   GBM-078-T-1                               NaN                 gbm
# 192  GBM-008-T-1B                               NaN                 gbm
# 195   GBM-084-T-1                               NaN                 NaN
#
#                                                aliases  collection_date_dfd  \
# 0                              GBM.ICB-1-10.533.A2-Pre                  0.0
# 3                                                  NaN                 23.0
# 9                                                  NaN                  0.0
# 20                                                 NaN                  0.0
# 23                       GBM.ICB-136-16.350.A2.Pre.add                  0.0
# 26                                                 NaN                  0.0
# 27                                                 NaN                  0.0
# 28                                                 NaN                  0.0
# 32                                                 NaN                300.0
# 35                       GBM.ICB-141-15.700.1B.Pre.add                  0.0
# 37              GBM.ICB-142-16.589.B.Pre.FFb, SM-JDD62                  0.0
# 40                                                 NaN                412.0
# 43              GBM.ICB-147-18.517.B.Pre.FFb, SM-JDD5N                  0.0
# 44                                                 NaN                250.0
# 47              GBM.ICB-17-15.256.A.Pre2.FFb, SM-JDKP1                 63.0
# 50                                                 NaN                  0.0
# 54                                            SM-JF38O                  0.0
# 60                                                 NaN                334.0
# 68                                                 NaN               1070.0
# 75                                                 NaN                147.0
# 77                                                 NaN                 10.0
# 78                     GBM.ICB-21-15.691.Pre, SM-JDKNZ                 10.0
# 82                                                 NaN                  0.0
# 86                                                 NaN                  0.0
# 87                                                 NaN                  0.0
# 88               GBM.ICB-23-16.087.A.Pre.FFb, SM-JDKOT                  0.0
# 93                                                 NaN                336.0
# 101                                                NaN                  0.0
# 106                                                NaN                  0.0
# 107              GBM.ICB-25-16.682.C.Pre.FFb, SM-JDD5E                  0.0
# 110                                                NaN                101.0
# 112                                                NaN                292.0
# 114                                                NaN                  0.0
# 118                                                NaN                  0.0
# 121                                                NaN                  0.0
# 123                                                NaN                  0.0
# 127                                                NaN                  0.0
# 128                                                NaN                113.0
# 133                                                NaN                  0.0
# 134             GBM.ICB-28-16.051.C.Pre2.FFb, SM-JDKPO                144.0
# 141                                           SM-JF38Q                  0.0
# 142                                                NaN                  0.0
# 144                                                NaN                  0.0
# 145                                                NaN                  0.0
# 150                                                NaN                  0.0
# 156                         GBM.ICB-37-16.964.B3.u.Pre                  0.0
# 161              GBM.ICB-39-16.227.B.Pre.FFb, SM-JDKP5                  0.0
# 165               GBM.ICB-4-14.535.2/1.u.Pre, SM-JF7IN                  0.0
# 168  GBM.ICB-42-14.422.A1B1.u.Pre.add, GBM.ICB-42-1...                  0.0
# 170                GBM.ICB-43-16.297.B.u.Pre, SM-JF7IR                  0.0
# 172                                                NaN                  0.0
# 174                                                NaN                150.0
# 179                                           SM-JDD5I                331.0
# 182              GBM.ICB-75-15.111.B.Pre.FFb, SM-JDKPA                  0.0
# 190                                                NaN                  0.0
# 192                                                NaN                  0.0
# 195                                                NaN                  0.0
#
#      has_RNA has_WES   irb_protocols no_normal original_material_type  ...  \
# 0       True    True          10-417     False                 tissue  ...
# 3       True    True          10-417     False                 tissue  ...
# 9       True    True          10-417      True                 tissue  ...
# 20     False    True          10-417     False                 tissue  ...
# 23      True    True          10-417      True                 tissue  ...
# 26      True    True          10-417     False                 tissue  ...
# 27      True    True          10-417     False                 tissue  ...
# 28      True    True          10-417     False                 tissue  ...
# 32      True    True          10-417     False                 tissue  ...
# 35      True    True          10-417      True                 tissue  ...
# 37      True    True  10-417, 17-682     False                 tissue  ...
# 40      True    True          10-417      True                 tissue  ...
# 43      True    True  10-417, 17-682     False                 tissue  ...
# 44      True    True          10-417     False                 tissue  ...
# 47      True    True  10-417, 17-682     False                 tissue  ...
# 50      True    True          10-417      True                 tissue  ...
# 54     False    True  10-417, 17-682      True                 tissue  ...
# 60      True    True          10-417     False                 tissue  ...
# 68      True    True          10-417     False                 tissue  ...
# 75      True    True          10-417     False                 tissue  ...
# 77      True    True          10-417     False                 tissue  ...
# 78      True    True  10-417, 17-682     False                 tissue  ...
# 82      True    True          10-417     False                 tissue  ...
# 86      True    True          10-417     False                 tissue  ...
# 87      True    True          10-417     False                 tissue  ...
# 88      True    True  10-417, 17-682     False                 tissue  ...
# 93      True    True          10-417     False                 tissue  ...
# 101     True    True          10-417     False                 tissue  ...
# 106     True    True          10-417      True                 tissue  ...
# 107     True    True  10-417, 17-682     False                 tissue  ...
# 110     True    True          10-417     False                 tissue  ...
# 112     True    True          10-417     False                 tissue  ...
# 114     True    True          10-417      True                 tissue  ...
# 118     True    True          10-417     False                 tissue  ...
# 121     True    True          10-417     False                 tissue  ...
# 123     True    True          10-417     False                 tissue  ...
# 127     True    True          10-417     False                 tissue  ...
# 128     True    True          10-417     False                 tissue  ...
# 133     True    True          10-417     False                 tissue  ...
# 134     True    True  10-417, 17-682     False                 tissue  ...
# 141    False    True          17-682     False                 tissue  ...
# 142     True    True          10-417      True                 tissue  ...
# 144     True    True  10-417, 17-682      True                 tissue  ...
# 145     True    True  10-417, 17-682      True                 tissue  ...
# 150     True    True          10-417     False                 tissue  ...
# 156     True    True          10-417     False                 tissue  ...
# 161     True    True  10-417, 17-682     False                 tissue  ...
# 165     True    True  10-417, 17-682     False                 tissue  ...
# 168     True    True  10-417, 17-682     False                 tissue  ...
# 170     True    True  10-417, 17-682      True                 tissue  ...
# 172     True    True          10-417     False                 tissue  ...
# 174     True    True          10-417     False                 tissue  ...
# 179     True    True  10-417, 17-682     False                 tissue  ...
# 182     True    True  10-417, 17-682     False                 tissue  ...
# 190     True    True          10-417     False                 tissue  ...
# 192     True    True          10-417     False                 tissue  ...
# 195     True    True          10-417     False                 tissue  ...
#
#     Exonic Rate Mapping Rate pdb_preservation_type usable_wes usable_rnaseq  \
# 0      0.880715     0.983749                   NaN       True         False
# 3      0.839242     0.990576                   NaN       True         False
# 9      0.877586     0.983330                   NaN       True         False
# 20          NaN          NaN                   NaN       True         False
# 23     0.916316     0.986380                   NaN       True          True
# 26     0.887162     0.962082                   NaN       True          True
# 27     0.846051     0.909367                   NaN       True         False
# 28     0.851592     0.988466                   NaN       True          True
# 32     0.902156     0.979729                   NaN       True          True
# 35     0.912824     0.980922                   NaN       True         False
# 37     0.862662     0.968330                   NaN       True          True
# 40     0.910073     0.980254                   NaN       True         False
# 43     0.829005     0.989275                   NaN       True          True
# 44     0.876288     0.987204                   NaN       True          True
# 47     0.834198     0.984275                   NaN       True          True
# 50     0.868213     0.945719                   NaN       True         False
# 54          NaN          NaN                   NaN       True         False
# 60     0.828735     0.989369                   NaN       True          True
# 68     0.860403     0.988575                   NaN       True         False
# 75     0.898187     0.984386                   NaN       True         False
# 77     0.901292     0.975416                   NaN       True          True
# 78     0.843586     0.989461                   NaN       True          True
# 82     0.815604     0.987794                   NaN       True         False
# 86     0.873045     0.982438                   NaN       True          True
# 87     0.889830     0.981063                   NaN       True          True
# 88     0.820842     0.979842                   NaN       True          True
# 93     0.869498     0.976742                   NaN       True          True
# 101    0.872509     0.992321                   NaN       True         False
# 106    0.880540     0.981620                   NaN       True         False
# 107    0.861514     0.990258                   NaN       True          True
# 110    0.874296     0.985428                   NaN       True         False
# 112    0.881081     0.981073                   NaN       True         False
# 114    0.831919     0.993313                   NaN       True         False
# 118    0.791630     0.991142                   NaN       True         False
# 121    0.862900     0.992639                   NaN       True         False
# 123    0.828749     0.988333                   NaN       True         False
# 127    0.822865     0.990381                   NaN       True         False
# 128    0.843822     0.985111                   NaN       True          True
# 133    0.864911     0.988532                   NaN       True         False
# 134    0.910438     0.917427                   NaN       True         False
# 141         NaN          NaN                   NaN       True         False
# 142    0.880911     0.986170                   NaN       True          True
# 144    0.877476     0.975005                   NaN       True          True
# 145    0.885839     0.976107                   NaN       True          True
# 150    0.899604     0.976180                   NaN       True         False
# 156    0.863068     0.982984                   NaN       True          True
# 161    0.740978     0.984137                   NaN       True          True
# 165    0.836895     0.974835                   NaN       True         False
# 168    0.891140     0.983545                   NaN       True         False
# 170    0.909533     0.984348                   NaN       True          True
# 172    0.906880     0.984523                   NaN       True         False
# 174    0.902530     0.985316                   NaN       True          True
# 179    0.864712     0.980994                   NaN       True          True
# 182    0.804147     0.797500                   NaN       True         False
# 190    0.830046     0.988537                   NaN       True          True
# 192    0.814729     0.607528                   NaN       True         False
# 195    0.868150     0.963926                   NaN       True          True
#
#     participant_id_legacy                 sample_id_legacy  DaysDxtoICB  \
# 0               GBM.ICB-1          GBM.ICB-1-10.533.B1.Pre       1786.0
# 3              GBM.ICB-10     GBM.ICB-10-14.178.B.Pre2.FFc        830.0
# 9             GBM.ICB-102           GBM.ICB-102-14.186.Pre        307.0
# 20            GBM.ICB-131     GBM.ICB-131-16.577.2-1.u.Pre         83.0
# 23            GBM.ICB-136        GBM.ICB-136-16.350.A2.Pre         49.0
# 26            GBM.ICB-139        GBM.ICB-139-16.266-Pre.A2         35.0
# 27            GBM.ICB-139        GBM.ICB-139-16.266-Pre.C5         35.0
# 28            GBM.ICB-139     GBM.ICB-139-16.266.B.Pre.FFc         35.0
# 32             GBM.ICB-14        GBM.ICB-14-16.702.B1.Pre2        425.0
# 35            GBM.ICB-141        GBM.ICB-141-15.700.1B.Pre        409.0
# 37            GBM.ICB-142    GBM.ICB-142-16.589.Pre.FFbank         29.0
# 40            GBM.ICB-144          GBM.ICB-144-18.442.Pre2        446.0
# 43            GBM.ICB-147    GBM.ICB-147-18.517.Pre.FFbank         31.0
# 44            GBM.ICB-153      GBM.ICB-153-18.239-FFb-Pre2        418.0
# 47             GBM.ICB-17    GBM.ICB-17-15.256.Pre2.FFbank         90.0
# 50            GBM.ICB-178       GBM.ICB-178-17.814-FFb-Pre        423.0
# 54             GBM.ICB-18        GBM.ICB-18-16.077.A14.Pre        407.0
# 60            GBM.ICB-190      GBM.ICB-190-19.776-FFb-Pre2        355.0
# 68              GBM.ICB-2      GBM.ICB-2-13.175.D.Pre2.FFc       1476.0
# 75             GBM.ICB-20      GBM.ICB-20-16.103.B1.u.Pre2        182.0
# 77             GBM.ICB-21         GBM.ICB-21-15.691-Pre.B3         34.0
# 78             GBM.ICB-21      GBM.ICB-21-15.691.A.Pre.FFc         34.0
# 82            GBM.ICB-212       GBM.ICB-212-12.321-FFb-Pre        684.0
# 86             GBM.ICB-22       GBM.ICB-22-16.173.B1.u.Pre         30.0
# 87             GBM.ICB-23     GBM.ICB-23-16.087-Pre.uss.B1         21.0
# 88             GBM.ICB-23     GBM.ICB-23-16.087.Pre.FFbank         21.0
# 93            GBM.ICB-232      GBM.ICB-232-18.927-FFb-Pre3        457.0
# 101           GBM.ICB-243       GBM.ICB-243-17.963.FFc-Pre        486.0
# 106           GBM.ICB-249      GBM.ICB-249-18.968.3-6u-Pre        519.0
# 107            GBM.ICB-25     GBM.ICB-25-16.682.Pre.FFbank         72.0
# 110           GBM.ICB-252       GBM.ICB-252-19.900.C1-Pre2        263.0
# 112           GBM.ICB-253       GBM.ICB-253-19.412.A2-Pre2        495.0
# 114           GBM.ICB-254       GBM.ICB-254-20.189.FFc-Pre        187.0
# 118           GBM.ICB-256       GBM.ICB-256-19.873-FFb-Pre        289.0
# 121           GBM.ICB-259       GBM.ICB-259-16.112.FFc-Pre       1515.0
# 123            GBM.ICB-26      GBM.ICB-26-16.226.B.Pre.FFc        238.0
# 127           GBM.ICB-260       GBM.ICB-260-20.927.FFc-Pre        181.0
# 128           GBM.ICB-262      GBM.ICB-262-19.557-FFb-Pre2        147.0
# 133            GBM.ICB-27      GBM.ICB-27-16.465.A.Pre.FFc        208.0
# 134            GBM.ICB-28    GBM.ICB-28-16.051.Pre2.FFbank        231.0
# 141            GBM.ICB-30         GBM.ICB-30.16.505.B6.Pre        269.0
# 142            GBM.ICB-31       GBM.ICB-31-16.199.3A.u.Pre        100.0
# 144            GBM.ICB-32       GBM.ICB-32-16.080.A1.u.Pre         28.0
# 145            GBM.ICB-32       GBM.ICB-32-16.080.A3.u.Pre         28.0
# 150            GBM.ICB-36         GBM.ICB-36-16.111.B3.Pre        328.0
# 156            GBM.ICB-37       GBM.ICB-37-16.964.B1.u.Pre         34.0
# 161            GBM.ICB-39     GBM.ICB-39-16.227.Pre.FFbank         35.0
# 165             GBM.ICB-4       GBM.ICB-4-14.535.2_1.u.Pre        425.0
# 168            GBM.ICB-42  GBM.ICB-42-14.422.A1B1_C1.u.Pre        646.0
# 170            GBM.ICB-43       GBM.ICB-43-16.297.B3.u.Pre         39.0
# 172             GBM.ICB-6          GBM.ICB-6-17.225.A2.Pre       1383.0
# 174            GBM.ICB-69        GBM.ICB-69-15.452.1B.Pre2        185.0
# 179             GBM.ICB-7     GBM.ICB-7-14.639.Pre3.FFbank        353.0
# 182            GBM.ICB-75     GBM.ICB-75-15.111.Pre.FFbank         30.0
# 190            GBM.ICB-78      GBM.ICB-78-15.615.A.Pre.FFc         22.0
# 192             GBM.ICB-8       GBM.ICB-8-13.353.C.Pre.FFb        273.0
# 195            GBM.ICB-84            GBM.ICB-84-16.832.Pre         29.0
#
#      collection_days_from_icb  latest_pre_date
# 0                     -1786.0          -1786.0
# 3                      -807.0           -807.0
# 9                      -307.0           -307.0
# 20                      -83.0            -83.0
# 23                      -49.0            -49.0
# 26                      -35.0            -35.0
# 27                      -35.0            -35.0
# 28                      -35.0            -35.0
# 32                     -125.0           -125.0
# 35                     -409.0           -409.0
# 37                      -29.0            -29.0
# 40                      -34.0            -34.0
# 43                      -31.0            -31.0
# 44                     -168.0           -168.0
# 47                      -27.0            -27.0
# 50                     -423.0           -423.0
# 54                     -407.0           -407.0
# 60                      -21.0            -21.0
# 68                     -406.0           -406.0
# 75                      -35.0            -35.0
# 77                      -24.0            -24.0
# 78                      -24.0            -24.0
# 82                     -684.0           -684.0
# 86                      -30.0            -30.0
# 87                      -21.0            -21.0
# 88                      -21.0            -21.0
# 93                     -121.0           -121.0
# 101                    -486.0           -486.0
# 106                    -519.0           -519.0
# 107                     -72.0            -72.0
# 110                    -162.0           -162.0
# 112                    -203.0           -203.0
# 114                    -187.0           -187.0
# 118                    -289.0           -289.0
# 121                   -1515.0          -1515.0
# 123                    -238.0           -238.0
# 127                    -181.0           -181.0
# 128                     -34.0            -34.0
# 133                    -208.0           -208.0
# 134                     -87.0            -87.0
# 141                    -269.0           -269.0
# 142                    -100.0           -100.0
# 144                     -28.0            -28.0
# 145                     -28.0            -28.0
# 150                    -328.0           -328.0
# 156                     -34.0            -34.0
# 161                     -35.0            -35.0
# 165                    -425.0           -425.0
# 168                    -646.0           -646.0
# 170                     -39.0            -39.0
# 172                   -1383.0          -1383.0
# 174                     -35.0            -35.0
# 179                     -22.0            -22.0
# 182                     -30.0            -30.0
# 190                     -22.0            -22.0
# 192                    -273.0           -273.0
# 195                     -29.0            -29.0
#
# [57 rows x 30 columns]

# %%
earliest_post_sample_df
# Out:
#         sample_id Broad_Name_add Histology  \
# 1     GBM-001-T-2            NaN       GBM
# 4     GBM-010-T-2            NaN       gbm
# 10    GBM-102-T-2            NaN       gbm
# 12    GBM-107-T-1            NaN       gbm
# 15   GBM-011-T-1A            NaN       gbm
# ..            ...            ...       ...
# 189   GBM-076-T-1            NaN       gbm
# 191   GBM-078-T-2            NaN    glioma
# 193   GBM-008-T-2            NaN       gbm
# 194   GBM-084-T-2            NaN       gbm
# 197   GBM-009-T-1            NaN       gbm
#
#                                                aliases  collection_date_dfd  \
# 1                GBM.ICB-1-15.228.B.Post.FFb, SM-JDD5Y               1884.0
# 4                 GBM.ICB-10-17.305.Post.FFb, SM-JDD5R                844.0
# 10                                                 NaN                397.0
# 12                                                 NaN                265.0
# 15                                                 NaN                606.0
# ..                                                 ...                  ...
# 189                    GBM.ICB-76-20.769.A2-Post.extra               1807.0
# 191             GBM.ICB-78-16.739.B.Post.FFb, SM-JDKOZ                348.0
# 193                    GBM.ICB-8-14.194.Post, SM-JDKOQ                339.0
# 194  GBM.ICB-84-16.138.B.Pre2.FFb, GBM.ICB-84-16.13...                 84.0
# 197                                                NaN                449.0
#
#      has_RNA has_WES   irb_protocols no_normal original_material_type  ...  \
# 1       True    True  10-417, 17-682     False                 tissue  ...
# 4       True    True  10-417, 17-682     False                 tissue  ...
# 10      True    True          10-417      True                 tissue  ...
# 12      True    True          10-417     False                 tissue  ...
# 15      True    True          10-417      True                 tissue  ...
# ..       ...     ...             ...       ...                    ...  ...
# 189     True    True          10-417     False                 tissue  ...
# 191     True    True  10-417, 17-682     False                 tissue  ...
# 193     True    True  10-417, 17-682     False                 tissue  ...
# 194     True    True  10-417, 17-682     False                 tissue  ...
# 197     True    True          10-417      True                 tissue  ...
#
#     Exonic Rate Mapping Rate pdb_preservation_type usable_wes usable_rnaseq  \
# 1      0.820317     0.985425                   NaN       True          True
# 4      0.852651     0.989419                   NaN       True          True
# 10     0.895114     0.984699                   NaN       True         False
# 12     0.879410     0.975860                   NaN       True          True
# 15     0.891150     0.970226                   NaN       True          True
# ..          ...          ...                   ...        ...           ...
# 189    0.873123     0.990121                   NaN       True          True
# 191    0.909551     0.937919                   NaN       True         False
# 193    0.456219     0.982462                   NaN       True         False
# 194    0.834741     0.983420                   NaN       True          True
# 197    0.769769     0.942844                   NaN       True         False
#
#     participant_id_legacy               sample_id_legacy  DaysDxtoICB  \
# 1               GBM.ICB-1   GBM.ICB-1-15.228.Post.FFbank       1786.0
# 4              GBM.ICB-10   GBM.ICB-10-17.305.A.Post.FFb        830.0
# 10            GBM.ICB-102  GBM.ICB-102-14.439.A.Post.FFc        307.0
# 12            GBM.ICB-107     GBM.ICB-107-18.067.A2.Post        259.0
# 15             GBM.ICB-11     GBM.ICB-11-17.000-Post2.C1         36.0
# ..                    ...                            ...          ...
# 189            GBM.ICB-76      GBM.ICB-76-20.769.A2-Post         33.0
# 191            GBM.ICB-78  GBM.ICB-78-16.739.Post.FFbank         22.0
# 193             GBM.ICB-8   GBM.ICB-8-14.194.Post.FFbank        273.0
# 194            GBM.ICB-84  GBM.ICB-84-16.138.Post.FFbank         29.0
# 197             GBM.ICB-9      GBM.ICB-9-15.703.uss.Post        282.0
#
#      collection_days_from_icb  earliest_post_date
# 1                        98.0                98.0
# 4                        14.0                14.0
# 10                       90.0                90.0
# 12                        6.0                 6.0
# 15                      570.0               570.0
# ..                        ...                 ...
# 189                    1774.0              1774.0
# 191                     326.0               326.0
# 193                      66.0                66.0
# 194                      55.0                55.0
# 197                     167.0               167.0
#
# [94 rows x 30 columns]

# %%
latest_pre_sample_df.to_csv("latest_pre_samples.tsv", sep="\t", index=None)

# %%
earliest_post_sample_df.to_csv("earliest_post_samples.tsv", sep="\t", index=None)
